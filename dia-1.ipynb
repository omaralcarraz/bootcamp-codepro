# %%
print("hola mundo")
# Out:
# hola mundo

# %%
fruta = "naranja"
print(fruta)

cantidad_frutas = 4
print(cantidad_frutas)
# Out:
# naranja
# 4

# %%
edad = 28 # int
altura = 1.85 # float
nombre = "omar" # str
feliz = True # bool

print(edad)
print(altura)
print(nombre)
print(feliz)
# Out:
# 28
# 1.85
# omar
# True

# %%
nombre="omar"
edad=28
ciudad="asuncion"
print(nombre, edad, ciudad)
# Out:
# omar 28 asuncion

# %%
producto1= "lomito"
costo_producto1=25000

producto2= "coca cola"
costo_producto2= 5000

capital = 50000
dolar = 6650

costo_total = costo_producto1 + costo_producto2
print("el costo total es", costo_total)

vuelto = capital - costo_total
print("el vuelto es", vuelto)

vuelto_dolares = vuelto / dolar
print("el vuelto en dolares es", vuelto_dolares)
# Out:
# el costo total es 30000
# el vuelto es 20000
# el vuelto en dolares es 3.007518796992481

# %% [markdown]
# Challenge 🤺 - 20m
# Suma: asignar dos números en dos variables diferentes cantidad_de_manzanas y cantidad_de_naranjas. Luego sumar ambas variables en cantidad_de_frutas. Imprimir la última variable.
#
# Resta: asignar un valor numérico a la variable frutas_vendidas. Luego, asignar la resta entre cantidad_de_frutas y frutas_vendidas a la variable frutas_restantes. Imprimir la última variable.

# %%
cantidad_naranjas = 10
cantidad_manzanas = 15
cantidad_frutas = cantidad_naranjas + cantidad_manzanas
print("la cantidad de frutas es", cantidad_frutas)

frutas_vendidas = 4
frutas_restantes = cantidad_frutas - frutas_vendidas

print("las frutas restantes son", frutas_restantes)
# Out:
# la cantidad de frutas es 25
# las frutas restantes son 21

# %% [markdown]
# #concatenacion

# %%
nombre = "omar"
apellido = "alcarraz"

print(nombre, apellido)

print(f"hola mi nombre es {nombre} {apellido}")
# Out:
# omar alcarraz
# hola mi nombre es omar alcarraz

# %% [markdown]
# Challenge 🤺 - 15m
# Asignar el nombre y el apellido de tu compañera/o a las variables nombre y apellido. Luego, imprimir una frase, utilizando las variables.
# EJEMPLO: "Hola. Me llamo Claudia Melgarejo. Mucho gusto."

# %%
nombre="claudia"
apellido="melgarejo"

print(f"Hola. me llamo {nombre} {apellido}. Mucho gusto")
# Out:
# Hola. me llamo claudia melgarejo. Mucho gusto

# %%
dato = input()
print(type(dato))
print(dato)
# Out:
# <class 'str'>
# hola

# %%
un_producto = input("que producto desea?")
print(un_producto)
print(f"Quisiera comprar un {un_producto}")
# Out:
# alfajor
# Quisiera comprar un alfajor

# %% [markdown]
# Challenge 🤺 – 10m
#
# 🎯 Objetivo: Practicar división y módulo.
#
# Imagina que estás repartiendo caramelos: solicita al usuario ingresar el total de caramelos y la cantidad de niños, luego calcula cuántos caramelos recibe cada niño usando división entera y cuántos sobran usando módulo, e imprime ambos resultados.

# %%
cant_caramelos=int(input("introduce la cantidad de caramelos"))
cant_ninhos=int(input("introduce la cantidad de ninhos"))

caramelos_x_ninho= cant_caramelos // cant_ninhos
sobrante= cant_caramelos % cant_ninhos

print(f"cada ninho recibe {caramelos_x_ninho}")
print(f"sobran {sobrante} caramelos")
# Out:
# cada ninho recibe 2
# sobran 1 caramelos

# %% [markdown]
# Challenge 🤺 - 15m
# Crear una función de un proceso que se les ocurra que tenga varios pasos.
#
# Ejecutar la función 3 veces.

# %%
def rutina():
    rutina = input("que cosas haces a la manhana?")
    print(rutina)
rutina()
rutina()
rutina()
# Out:
# ejercicio
# comer
# banharme

# %% [markdown]
# Challenge 🤺 - 25m
#
# Escribir una funcion que represente un sistema de pedidos de comida rapida.
#
# La funcion debe recibir como parametros el nombre del producto y el tamaño del pedido.
#
# Al ejecutarse, debe imprimir en pantalla el detalle del pedido de forma clara y ordenada.
#
# Luego, llamar a la funcion pasando los argumentos correspondientes para simular que un cliente realiza un pedido.

# %%
pedido1 = input("ingrese el pedido de comida")
cant1 = input("ingresa la cantidad del pedido")

def preparacion(pedido, cant):
    print(f"preparando el pedido de {cant1} {pedido1}/s" )
    print("El pedido ya esta listo, que disfrutes tu comida!!")
preparacion(pedido1, cant1)
# Out:
# preparando el pedido de 3 pizza/s
# El pedido ya esta listo, que disfrutes tu comida!!

# %% [markdown]
# Challenge 🤺 - 10m
#
# 🎯 Objetivo:
# Practicar variables globales y locales.
#
# Escribir una función calcular_total que reciba el precio de un producto y calcule el total sumando un impuesto global impuesto = 10.
# Usa una variable local total para almacenar el resultado e imprime el total.
# Llama a la función con distintos precios para probar.

# %%
impuesto = 1.1

def calcular_total(producto, precio):
    producto = input("introduce un producto")
    precio = int(input("introduce el precio"))
    precio_con_impuesto = precio * impuesto
    print(f"el precio de {producto} es {precio_con_impuesto} impuestos incluidos")

calcular_total(producto, precio)
calcular_total(producto, precio)
calcular_total(producto, precio)
# Out:
# el precio de agua es 11.0 impuestos incluidos
# el precio de pan es 11.0 impuestos incluidos
# el precio de carne es 11.0 impuestos incluidos
